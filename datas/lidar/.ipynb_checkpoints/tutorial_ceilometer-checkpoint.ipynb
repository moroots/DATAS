# %% [markdown]
# # Ceilometer Tutorial
# ### Using the ceilometer function in the DATAS package
#
# Author: Maurice Roots

# %% [markdown]
# ---
# #### Importing Packages

# %%
from datas.lidar import ceilometer

# %% [markdown]
# **Define your filepaths (AS A LIST !!!)**

# %%
FilePaths = [r"G:\My Drive\SaSa 2022\Data\Howard\2022\Ceilometer\20210606_HUBV_CHM160113_000.nc"]

# %% [markdown]
# The function *importing_ceilometer* outputs a dictionary of all extracted data and one of xarrays files.

# %%
data, files = ceilometer.importing_ceilometer(FilePaths)

# %% [markdown]
# The function *plot* will create a standard ceilometer curtain for quick visualization.

# %%
ceilometer.plot(data)
