# %% [markdown]
# # Ceilometer Data Processing (L1)
# L1 Contains
#  - Standardized File (5760, 1024)
#  - RCS 10 min average
#  - CBL 30 min
#  - Precipitaiton Mask
#  - Readable Timestamp & np.datetime64
#
#
#  **designed to work ONLY on CHM15k Nimbus. The functions will check...**

# %% [markdown]
# ---
# #### Importing Packages
# ---

# %%
# ploting
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.colors import LogNorm
import matplotlib.units as munits

# data processing
from scipy.signal import savgol_filter
from scipy.signal import find_peaks
from netCDF4 import Dataset
import xarray as xr
import pandas as pd


# utilities
from datetime import datetime
from pathlib import Path
from numba import jit
import numpy as np
from copy import deepcopy
from datetime import date

# %% [markdown]
# ---
# #### Function Space
# ---

# %% [markdown]
# **Importing Data**

# %%
def importing(FilePaths, standard_time=True, **kwargs):
    
    data = {} # creating a dictionary to hold all the data imported
    filePaths = [Path(filePath) for filePath in FilePaths] # converting to Pathlib objects

    # Using a loop to import each file from FilePaths
    for filePath in filePaths:

        # Validating supplied path
        if filePath.is_file() is False:
            print('PATH IS NOT FOUND ON MACHINE')
            return

        # Creating a nested dictionary
        data[filePath.name] = {}

        # Using Xarrays to import each NetCDF4 file
        with xr.open_dataset(filePath) as file:
            if file.title != "CHM15k Nimbus":
                print("This module is only apporved for use with CHM15k Nimbus datasets")
                return

            data[filePath.name]["dataset"] =  file # This contains EVERYTHING inside the file
            data[filePath.name]["lat_lon_elevation"] = [file.longitude.values, file.latitude.values, file.altitude.values]
            
            if standard_time == True:
                origin = file.time.values[0].astype('datetime64[D]')
                print(origin)
                # data[filePath.name]["RCS"] = np.zeros((file.beta_raw.shape[0]+1, file.beta_raw.shape[1]))
                # data[filePath.name]["RCS"][0,:] = file.beta_raw[0, :]
                # data[filePath.name]["RCS"].time[0] = origin
                data[filePath.name]["RCS"] = file.beta_raw.resample(time="15s", frequency="24H").mean()
                # data[filePath.name]["RCS"] = file.beta_raw
                # data[filePath.name]["RCS"].time[0] = origin
            else:
                data[filePath.name]["RCS"] = file.beta_raw

    return data, list(data.keys())

# %% [markdown]
# **Precipitation Filter**

# %%
def filter_precip(dataArray, precip_signal_threshold = 4e5):
    
    # Define number of times to loop
    ntimes = dataArray.time.shape[0]

    # Initialize precip flag array
    precip = np.zeros(ntimes)
    precip[:] = np.nan

    # Define index of 200m for top boundary of precip
    index_200m = np.where(dataArray.range<=200)[0][-1]+1
    # print(index_200m)

    # Loop all times to find precip
    for t in np.arange(ntimes):

        # Label signal to 1/0 if over/under threshold defined
        uL = dataArray.T.values
        precip_flag = uL[:index_200m,t] >= precip_signal_threshold

        # Find sum of column observations under 200m under threshold
        false_flags = sum(precip_flag==False)

        if false_flags==0:  # If no observations fall under threshold, mark as precip (1)
            precip[t]=1
        elif false_flags>=1: # If any observations fall over threshold, mark as (0)
            precip[t]=0

    # Change to integer array
    precip = precip.astype(int)

    # Add precip flag to data dictionary
    pflags = pd.DataFrame({"datetime": dataArray.time, "flag": precip})

    return pflags

# %% [markdown]
# **Haar Wavelet**

# %%
@jit(nopython=True)
def haar(length,a,b):

    # Zero Array to fill in Wavelet
    wavelet = np.zeros(length)
    
    # Haar Wavelet (see eqn 1 screenshot)
    wavelet[np.int64(b - a):np.int64(b)] = -1
    wavelet[np.int64(b):np.int64(b + a)] = 1
    wavelet[b] = 0

    return wavelet

# %% [markdown]
# **Covariance Profile**

# %%
@jit(nopython=True)
def covariance_profile(profile,a,alts):

    # Initialize covariance array
    w = np.zeros(alts.shape[0])
    wavelets = np.zeros((alts.shape[0], alts.shape[0]))
    
    # Height boundaries for wavelet
    z_top = np.int64(a)+1
    z_bot = profile.shape[0]-np.int64(a)-1

    # Calculate covariance coefficients and fill covariance array for each altitude
    f = profile
    for z in np.arange(0, len(alts)):
        wavelets[z] = haar(len(alts), a, z)
        w[z] = np.nansum(f * wavelets[z]) / a

    return w, f, wavelets

# %%
def coef_avg(prof, a_vals):
    c_avg = np.zeros(prof.shape)
    for i in np.arange(prof.shape[0]):
        c = np.zeros((prof.shape[1], len(a_vals)))
        
        for a, j in zip(a_vals, np.arange(0, c.shape[1])):
            cwt, f, wavelets = covariance_profile(prof[i, :], a, alts)
            c[:, j] = cwt

        c_avg[i, :] = np.mean(c, axis=1)
    return c_avg

# %% [markdown]
# ---
# #### Work Space
# ---

# %% [markdown]
# **Importing File**

# %% [markdown]
# **I begin by** importing the data file and visually inspecting the elements.

# %%
FilePaths = [r'C:\Users\Magnolia\OneDrive - UMBC\Research\Analysis\Process\TRACER-AQ\ceilometer\20210809\20210809_TROPOZ_CHM200123_000.nc']
Data, keys = importing(FilePaths, standard_time=False)
print(Data)
# Out:
# {'20210809_TROPOZ_CHM200123_000.nc': {'dataset': <xarray.Dataset>
# Dimensions:         (time: 1839, range: 1024, range_hr: 32, layer: 3)
# Coordinates:
#   * time            (time) datetime64[ns] 2021-08-09T16:20:28 ... 2021-08-09T...
#   * range           (range) float32 14.98 29.97 44.96 ... 1.533e+04 1.534e+04
#   * range_hr        (range_hr) float32 0.001 4.995 9.99 ... 144.9 149.9 154.8
#   * layer           (layer) int32 1 2 3
# Data variables: (12/41)
#     latitude        float32 3.9e-05
#     longitude       float32 -7.6e-05
#     azimuth         float32 ...
#     zenith          float32 ...
#     altitude        float32 0.0
#     wavelength      float32 ...
#     ...              ...
#     cdp             (time, layer) int16 ...
#     cde             (time, layer) int16 ...
#     cho             int16 ...
#     nn1             (time) int16 ...
#     nn2             (time) int16 ...
#     nn3             (time) int16 ...
# Attributes: (12/15)
#     title:             CHM15k Nimbus
#     source:            CHM200123
#     device_name:       CHM200123
#     serlom:            TUB200024
#     day:               9
#     month:             8
#     ...                ...
#     wmo_id:            0
#     wigos_id:
#     netcdf_mode:       2
#     software_version:  18.10.1 2.13 1.070 0
#     comment:
#     overlap_file:      TUB200024 (2020-11-23 14:27:31), 'lat_lon_elevation': [array(-7.6e-05, dtype=float32), array(3.9e-05, dtype=float32), array(0., dtype=float32)], 'RCS': <xarray.DataArray 'beta_raw' (time: 1839, range: 1024)>
# [1883136 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2021-08-09T16:20:28 ... 2021-08-09T23:59:56
#   * range    (range) float32 14.98 29.97 44.96 ... 1.531e+04 1.533e+04 1.534e+04
# Attributes:
#     units:
#     long_name:  normalized range corrected signal\n((P_raw / lp) - b) / (cs *...}}

# %%
test = deepcopy(Data[keys[0]]["RCS"])
standard = pd.DataFrame(test, index=test.time)
print(standard.shape)
# Out:
# (1839, 1024)

# %%
standard = standard.resample(rule="15s", origin="2021-08-09 00:00").mean()
print(standard.shape)
# Out:
# (1839, 1024)

# %% [markdown]
# **After inspection,** I create three new variables; 10 min averaged RCS (*RCS_10min*), a precipitation mask (*precip_mask*), and standardized RCS (*RCS_flt*) which has the precipitation mask applied.

# %%
Data[keys[0]]["precip_flt"] = filter_precip(Data[keys[0]]["RCS"])
Data[keys[0]]["RCS_flt"] = Data[keys[0]]["RCS"]
Data[keys[0]]["RCS_flt"].values[Data[keys[0]]["precip_flt"].flag == 1] = np.nan
Data[keys[0]]["RCS_10min"] = Data[keys[0]]["RCS_flt"].resample(time="10min").mean()

print(Data[keys[0]].keys())
print(Data[keys[0]]["RCS"].shape)
# Out:
# dict_keys(['dataset', 'lat_lon_elevation', 'RCS', 'precip_flt', 'RCS_flt', 'RCS_10min'])
# (1839, 1024)

# %% [markdown]
# **Here I define** some parameters for the planetary boundary layer height retrieval. I'm using   300 m - 4000 m as a vertical window. Values of "a" for the Haar wavelet go from 1 - 500 in increments of 5.

# %%
data = deepcopy(Data[keys[0]])
a_vals = np.arange(1,25,1)
alt_constraint = [300, 4000]
profile_index = 2
parms = {"width":5, "distance":50, "prominence":(5e4, 9e6)}

# %%
alt_start, alt_stop = (np.argmax(data["RCS_10min"].range.values >= alt_constraint[0]), np.argmax(data["RCS_10min"].range.values >= alt_constraint[1]))
profile = data["RCS_10min"][:, alt_start:alt_stop]
alts = profile.range.values

# %% [markdown]
# **Now I preallocate** some variables for the the covariance wavelent transform. And then loop through the profiles of data.

# %%
c = np.zeros((profile.values[0, :].shape[0], len(a_vals)))

for a, j in zip(a_vals, np.arange(0, c.shape[1])):
    cwt, f, wavelets = covariance_profile(profile.values[profile_index, :], a, alts)
    c[:, j] = cwt
    
c_avg = np.nanmean(c, axis=1)

peaks, properties = find_peaks(-1*c_avg, **parms)

fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10,12))
ax[0].plot(f, alts)
ax[0].set_ylabel("Altitude (m AGL)", fontsize=16)
ax[0].set_title("Ceilometer RCS", fontsize=16)

ax[1].pcolormesh(a_vals, alts, -1*c, cmap="jet")
ax[1].set_title("Coef. CWT", fontsize=16)

ax[2].plot(c_avg, alts)
ax[2].plot(c_avg[peaks], alts[peaks], "ko")
ax[2].set_ylim(alts[0], alts[-1])
ax[2].set_title("Avg. Coef. CWT", fontsize=16)

plt.suptitle(f"Profile at {np.datetime_as_string(profile.time[profile_index].values, unit='m')}", fontsize=18)
plt.tight_layout()

# %% [markdown]
# ---
# #### Applying to whole profile
# ---

# %% [markdown]
# **Finding Peaks**

# %%
C_avg = coef_avg(profile.values, a_vals)

peak_index = np.zeros((C_avg.shape[0], 50))
peak_prominence = np.zeros((C_avg.shape[0], 50))

for i in np.arange(0, C_avg.shape[0]):
    peaks, properties = find_peaks(-1*C_avg[i, :], **parms)

    order_test = sorted(((value, index) for index, value in enumerate(properties["prominences"])))
    for j in range(0, len(peaks)):
        peak_index[i, j] = peaks[order_test[j][1]]
        peak_prominence[i, j] = order_test[j][0]

peak_index = np.int64(peak_index)
print(peak_index)
# Out:
# [[ 57   0   0 ...   0   0   0]
#  [ 55   0   0 ...   0   0   0]
#  [ 66   0   0 ...   0   0   0]
#  ...
#  [ 53   0   0 ...   0   0   0]
#  [211  39   0 ...   0   0   0]
#  [ 53   0   0 ...   0   0   0]]

# %%
test = Data[keys[0]]["RCS"]

plt.figure(figsize=(10,10))
plt.pcolormesh(test.time, test.range, test.T, cmap='jet', norm=LogNorm(),shading='auto')
plt.clim(vmin=10**5, vmax=10**5.5)
plt.ylim([0,4000])

for i in np.arange(0, 5):
    plt.plot(profile.time, alts[peak_index[:, i]], "*", color="pink", markersize=20)

# %% [markdown]
# **Choosing Peaks**

# %%
res = np.ceil(np.mean([np.abs(alts[i-1] - alts[i]) for i in np.arange(1, len(alts))] ))

pblh = np.zeros(profile.shape[0])
pblh[0] = peak_index[0,0]

for i in np.arange(1, profile.shape[0]): 
    k = np.abs(pblh[np.nonzero(pblh)[0][-1]] - peak_index[i, :])
    print(k)
    
    m = np.argmin(k)
    
    if i < (50):
        Dy = 300
    else: 
        Dy = 1000
        
    if k[m] < (Dy / res): 
        pblh[i] = peak_index[i, m]
# Out:
# [ 2. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57.
#  57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57.
#  57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57. 57.]
# [11. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55.
#  55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55.
#  55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55. 55.]
# [ 5. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66.
#  66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66.
#  66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66. 66.]
# [168.   1.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.]
# [160.  30.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.
#   60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.
#   60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.
#   60.  60.  60.  60.  60.  60.  60.  60.]
# [132.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.
#   60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.
#   60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.
#   60.  60.  60.  60.  60.  60.  60.  60.]
# [148.   2.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.
#   60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.
#   60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.  60.
#   60.  60.  60.  60.  60.  60.  60.  60.]
# [169.   4.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.
#   58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.
#   58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.
#   58.  58.  58.  58.  58.  58.  58.  58.]
# [16. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62.
#  62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62.
#  62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62. 62.]
# [105.  12.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.
#   46.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.
#   46.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.  46.
#   46.  46.  46.  46.  46.  46.  46.  46.]
# [175.  48.   3.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.
#   58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.
#   58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.
#   58.  58.  58.  58.  58.  58.  58.  58.]
# [171.   3.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.
#   55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.
#   55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.
#   55.  55.  55.  55.  55.  55.  55.  55.]
# [86. 10. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58.
#  58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58.
#  58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58. 58.]
# [43. 10. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68.
#  68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68.
#  68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68. 68.]
# [137.   5.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.
#   58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.
#   58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.  58.
#   58.  58.  58.  58.  58.  58.  58.  58.]
# [83.  3. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63.
#  63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63.
#  63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63.]
# [ 91. 145.   5.  66.  66.  66.  66.  66.  66.  66.  66.  66.  66.  66.
#   66.  66.  66.  66.  66.  66.  66.  66.  66.  66.  66.  66.  66.  66.
#   66.  66.  66.  66.  66.  66.  66.  66.  66.  66.  66.  66.  66.  66.
#   66.  66.  66.  66.  66.  66.  66.  66.]
# [164.   1.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.]
# [159.   2.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.
#   62.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.
#   62.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.  62.
#   62.  62.  62.  62.  62.  62.  62.  62.]
# [108.   1.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.
#   64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.
#   64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.
#   64.  64.  64.  64.  64.  64.  64.  64.]
# [32. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63.
#  63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63.
#  63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63. 63.]
# [117.   0.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.
#   63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.
#   63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.
#   63.  63.  63.  63.  63.  63.  63.  63.]
# [136.   2.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.
#   63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.
#   63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.  63.
#   63.  63.  63.  63.  63.  63.  63.  63.]
# [12. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61.
#  61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61.
#  61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61. 61.]
# [ 52. 119.  12.  73.  73.  73.  73.  73.  73.  73.  73.  73.  73.  73.
#   73.  73.  73.  73.  73.  73.  73.  73.  73.  73.  73.  73.  73.  73.
#   73.  73.  73.  73.  73.  73.  73.  73.  73.  73.  73.  73.  73.  73.
#   73.  73.  73.  73.  73.  73.  73.  73.]
# [157.  25.  46.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.]
# [125.  37.  40.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.]
# [156.   6.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.  61.
#   61.  61.  61.  61.  61.  61.  61.  61.]
# [128. 184.  10.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.
#   55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.
#   55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.  55.
#   55.  55.  55.  55.  55.  55.  55.  55.]
# [56. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65.
#  65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65.
#  65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65. 65.]
# [174. 124.   5.  65.  65.  65.  65.  65.  65.  65.  65.  65.  65.  65.
#   65.  65.  65.  65.  65.  65.  65.  65.  65.  65.  65.  65.  65.  65.
#   65.  65.  65.  65.  65.  65.  65.  65.  65.  65.  65.  65.  65.  65.
#   65.  65.  65.  65.  65.  65.  65.  65.]
# [149.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.
#   70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.
#   70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.
#   70.  70.  70.  70.  70.  70.  70.  70.]
# [162.   1.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.
#   70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.
#   70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.  70.
#   70.  70.  70.  70.  70.  70.  70.  70.]
# [71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71.
#  71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71.
#  71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71.]
# [109.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.
#   71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.
#   71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.  71.
#   71.  71.  71.  71.  71.  71.  71.  71.]
# [ 1. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71.
#  71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71.
#  71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71. 71.]
# [ 5. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72.
#  72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72.
#  72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72. 72.]
# [13. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77.
#  77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77.
#  77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77. 77.]
# [ 61. 164.   5.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.
#   64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.
#   64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.  64.
#   64.  64.  64.  64.  64.  64.  64.  64.]
# [169.  18.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.
#   69.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.
#   69.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.  69.
#   69.  69.  69.  69.  69.  69.  69.  69.]
# [27. 45. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51.
#  51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51.
#  51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51. 51.]
# [163.   2.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.
#   51.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.
#   51.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.  51.
#   51.  51.  51.  51.  51.  51.  51.  51.]
# [ 0. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53.
#  53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53.
#  53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53. 53.]
# [158.  14.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.
#   53.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.
#   53.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.  53.
#   53.  53.  53.  53.  53.  53.  53.  53.]
# [14. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39.
#  39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39.
#  39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39.]

# %%
print(peak_index[0, 0])
print(k)
print(m)
print(pblh)
# Out:
# 57
# [14. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39.
#  39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39.
#  39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39. 39.]
# 0
# [57. 55. 66. 61. 60.  0.  0. 58. 62. 46. 58. 55. 58. 68. 58. 63. 66. 61.
#  62. 64. 63.  0. 63. 61. 73. 61.  0.  0. 55. 65.  0. 70.  0. 71.  0.  0.
#  72. 77. 64. 69. 51.  0. 53. 53. 39. 53.]

# %%
test = Data[keys[0]]["RCS"]

plt.figure(figsize=(15,10))
plt.pcolormesh(test.time, test.range, test.T, cmap='jet', norm=LogNorm(),shading='auto')
plt.clim(vmin=10**5, vmax=10**5.5)
plt.ylim([0,4000])

plt.plot(profile.time, alts[np.int64(pblh)], "*", color="pink", markersize=20)

# %% [markdown]
# The values at the bottom are not retrieved pblh. They are just zero indexies of the altitude array. They will be masked as NaN values in the final.

# %%
def create_nc(data, folderPath, **kwargs):
    
    try: ncfile.close()
    except: pass 
    
    fileName = f"traceraq-GSFCCeilometer_LaPorte_20210913_L1"
    ncfile = Dataset(r'{}.nc'.format(fileName), mode="w", format="NETCDF4_CLASSIC")
    print(ncfile)
    
    dim_alt = ncfile.createDimension("altitude", 1040)
    dim_time  = ncfile.createDimension("time", 0)
    
    for dim in ncfile.dimensions.items():
        print(dim)
    
    ncfile.title = "CHM15K Nimbus"
    ncfile.history = f"Created by Maurice Roots ({date.today()})"
    ncfile.institution = "GSFC / Sullivan TOLNET"
    ncfile.location = "La Port, TX"
    ncfile.version = "L1"
    ncfile.processing = "DATAS v2022.03.30"
    ncfile.usage = "TRACER-AQ"
    
    # time = ncfile.createVariable("time", )
    
    altiude = ncfile.createVariable("altitude", "f4", ("altitude",), )
    altitude = data["RCS"].range
    
    print(ncfile)
    ncfile.close()
    
    return

# %%
create_nc(data, r"data")
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes):
#     variables(dimensions):
#     groups:
# ('altitude', <class 'netCDF4._netCDF4.Dimension'>: name = 'altitude', size = 1040)
# ('time', <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 0)
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     title: CHM15K Nimbus
#     history: Created by Maurice Roots (2022-03-31)
#     institution: GSFC / Sullivan TOLNET
#     location: La Port, TX
#     version: L1
#     processing: DATAS v2022.03.30
#     usage: TRACER-AQ
#     dimensions(sizes): altitude(1040), time(0)
#     variables(dimensions): float32 altitude(altitude)
#     groups:
